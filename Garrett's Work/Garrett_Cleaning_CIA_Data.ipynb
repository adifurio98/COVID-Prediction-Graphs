# %%
# This Notebook was used to create the first version of cleaned data of the World Factbook for use in our EDA.

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
countries_df = pd.read_csv("Data/countries.csv")
countries_df.head()
# Out:
#      Country                                                url  \
# 0    Austria  https://www.cia.gov/the-world-factbook/countri...
# 1     Greece  https://www.cia.gov/the-world-factbook/countri...
# 2      India  https://www.cia.gov/the-world-factbook/countri...
# 3  Indonesia  https://www.cia.gov/the-world-factbook/countri...
# 4       Iran  https://www.cia.gov/the-world-factbook/countri...
#
#                             Introduction: Background  \
# 0  Once the center of power for the large Austro-...
# 1  Greece achieved independence from the Ottoman ...
# 2  The Indus Valley civilization, one of the worl...
# 3  The archipelago was once largely under the con...
# 4  Known as Persia until 1935, Iran became an Isl...
#
#                                  Geography: Location  \
# 0        Central Europe, north of Italy and Slovenia
# 1  Southern Europe, bordering the Aegean Sea, Ion...
# 2  Southern Asia, bordering the Arabian Sea and t...
# ...

# %%
countries_df = countries_df[["Country", "People and Society: Current Health Expenditure", "People and Society: Physicians density", "People and Society: Hospital bed density", "Geography: Area - total", "Economy: Real GDP (purchasing power parity)", "Economy: Real GDP per capita", "Economy: GDP (official exchange rate)", "People and Society: Population", "Country"]]
countries_df.head()
# Out:
#      Country People and Society: Current Health Expenditure  \
# 0    Austria                                   10.4% (2019)
# 1     Greece                                    7.8% (2019)
# 2      India                                      3% (2019)
# 3  Indonesia                                    2.9% (2019)
# 4       Iran                                    6.7% (2019)
#
#     People and Society: Physicians density  \
# 0  5.29 physicians/1,000 population (2020)
# 1  6.31 physicians/1,000 population (2019)
# 2  0.74 physicians/1,000 population (2020)
# 3  0.62 physicians/1,000 population (2020)
# 4  1.58 physicians/1,000 population (2018)
#
#   People and Society: Hospital bed density Geography: Area - total  \
# 0         7.3 beds/1,000 population (2018)            83,871 sq km
# 1         4.2 beds/1,000 population (2018)           131,957 sq km
# 2         0.5 beds/1,000 population (2017)         3,287,263 sq km
# 3           1 beds/1,000 population (2017)         1,904,569 sq km
# ...

# %%
countries_df.to_csv('cia_cleaned.csv', index=False)
